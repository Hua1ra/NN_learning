# %%
import matplotlib.pyplot as plt # type: ignore
import torch # type: ignore
from src.CasiaWebface import CasiaWebface # type: ignore
from src.Detector import Detector # type: ignore
from PIL import Image # type: ignore

# %%
dataset = CasiaWebface(rec_path='./data/casia-webface/train.rec',
                       idx_path='./data/casia-webface/train.idx')
dataloader = torch.utils.data.DataLoader(dataset, batch_size=1, shuffle=False)
detector = Detector(model_path='./models/yolov8n-face.pt', transformer=None)
detector.detect()

# %%
image, label = dataset[13]
plt.axis('off')
plt.imshow(image)
plt.show()
image = detector(image)
if image is not None:
    plt.axis('off')
    image = image.resize((224, 224))
    plt.imshow(image)
    plt.show()
else:
    print('No faces detected')
# Out:
# 0: 640x640 1 face, 62.3ms
# Speed: 3.0ms preprocess, 62.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
